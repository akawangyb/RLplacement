# %%
import torch

torch.manual_seed(0)

import time

from torchrl.envs import GymEnv, StepCounter, TransformedEnv

env = TransformedEnv(GymEnv("CartPole-v1"), StepCounter())
env.set_seed(0)

from tensordict.nn import TensorDictModule as Mod, TensorDictSequential as Seq

# %%
from torchrl.modules import EGreedyModule, MLP, QValueModule

value_mlp = MLP(out_features=env.action_spec.shape[-1], num_cells=[64, 64])
value_net = Mod(value_mlp, in_keys=["observation"], out_keys=["action_value"])
policy = Seq(value_net, QValueModule(env.action_spec))
exploration_module = EGreedyModule(
    env.action_spec, annealing_num_steps=100_000, eps_init=0.5
)
policy_explore = Seq(policy, exploration_module)
# Out:
# D:\python39\lib\site-packages\torch\nn\modules\lazy.py:181: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
from torchrl.collectors import SyncDataCollector
from torchrl.data import LazyTensorStorage, ReplayBuffer

init_rand_steps = 5000
frames_per_batch = 100
optim_steps = 10
collector = SyncDataCollector(
    env,
    policy,
    frames_per_batch=frames_per_batch,
    total_frames=-1,
    init_random_frames=init_rand_steps,
)
rb = ReplayBuffer(storage=LazyTensorStorage(100_000))

from torch.optim import Adam

# %%
from torchrl.objectives import DQNLoss, SoftUpdate

loss = DQNLoss(value_network=policy, action_space=env.action_spec, delay_value=True)
optim = Adam(loss.parameters(), lr=0.02)
updater = SoftUpdate(loss, eps=0.99)

# %%
from torchrl._utils import logger as torchrl_logger
from torchrl.record import CSVLogger, VideoRecorder

path = "./training_loop"
logger = CSVLogger(exp_name="dqn", log_dir=path, video_format="mp4")
video_recorder = VideoRecorder(logger, tag="video")
record_env = TransformedEnv(
    GymEnv("CartPole-v1", from_pixels=True, pixels_only=False), video_recorder
)

# %%
total_count = 0
total_episodes = 0
t0 = time.time()
for i, data in enumerate(collector):
    # Write data in replay buffer
    rb.extend(data)
    max_length = rb[:]["next", "step_count"].max()
    if len(rb) > init_rand_steps:
        # Optim loop (we do several optim steps
        # per batch collected for efficiency)
        for _ in range(optim_steps):
            sample = rb.sample(128)
            loss_vals = loss(sample)
            loss_vals["loss"].backward()
            optim.step()
            optim.zero_grad()
            # Update exploration factor
            exploration_module.step(data.numel())
            # Update target params
            updater.step()
            if i % 10:
                torchrl_logger.info(f"Max num steps: {max_length}, rb length {len(rb)}")
            total_count += data.numel()
            total_episodes += data["next", "done"].sum()
    if max_length > 200:
        break

t1 = time.time()

torchrl_logger.info(
    f"solved after {total_count} steps, {total_episodes} episodes and in {t1-t0}s."
)
# Out:
# 2024-04-24 17:56:17,297 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-04-24 17:56:17,309 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-04-24 17:56:17,322 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-04-24 17:56:17,337 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-04-24 17:56:17,352 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-04-24 17:56:17,368 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-04-24 17:56:17,381 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-04-24 17:56:17,396 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-04-24 17:56:17,412 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-04-24 17:56:17,426 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-04-24 17:56:17,592 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-04-24 17:56:17,605 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-04-24 17:56:17,619 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-04-24 17:56:17,634 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-04-24 17:56:17,647 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-04-24 17:56:17,660 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-04-24 17:56:17,672 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-04-24 17:56:17,687 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-04-24 17:56:17,700 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-04-24 17:56:17,713 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-04-24 17:56:17,893 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-04-24 17:56:17,906 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-04-24 17:56:17,919 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-04-24 17:56:17,935 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-04-24 17:56:17,951 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-04-24 17:56:17,966 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-04-24 17:56:17,980 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-04-24 17:56:17,996 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-04-24 17:56:18,012 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-04-24 17:56:18,027 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-04-24 17:56:18,189 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-04-24 17:56:18,203 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-04-24 17:56:18,215 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-04-24 17:56:18,229 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-04-24 17:56:18,244 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-04-24 17:56:18,259 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-04-24 17:56:18,278 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-04-24 17:56:18,296 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-04-24 17:56:18,315 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-04-24 17:56:18,330 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-04-24 17:56:18,497 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-04-24 17:56:18,514 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-04-24 17:56:18,528 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-04-24 17:56:18,547 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-04-24 17:56:18,561 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-04-24 17:56:18,579 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-04-24 17:56:18,596 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-04-24 17:56:18,620 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-04-24 17:56:18,641 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-04-24 17:56:18,661 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-04-24 17:56:18,866 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-04-24 17:56:18,878 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-04-24 17:56:18,894 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-04-24 17:56:18,918 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-04-24 17:56:18,936 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-04-24 17:56:18,957 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-04-24 17:56:18,977 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-04-24 17:56:18,997 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-04-24 17:56:19,017 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-04-24 17:56:19,033 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-04-24 17:56:19,252 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-04-24 17:56:19,271 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-04-24 17:56:19,292 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-04-24 17:56:19,312 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-04-24 17:56:19,333 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-04-24 17:56:19,350 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-04-24 17:56:19,370 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-04-24 17:56:19,390 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-04-24 17:56:19,405 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-04-24 17:56:19,429 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-04-24 17:56:19,636 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-04-24 17:56:19,650 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-04-24 17:56:19,668 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-04-24 17:56:19,682 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-04-24 17:56:19,699 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-04-24 17:56:19,715 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-04-24 17:56:19,731 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-04-24 17:56:19,747 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-04-24 17:56:19,764 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-04-24 17:56:19,783 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-04-24 17:56:19,997 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-04-24 17:56:20,013 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-04-24 17:56:20,029 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-04-24 17:56:20,045 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-04-24 17:56:20,065 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-04-24 17:56:20,084 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-04-24 17:56:20,099 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-04-24 17:56:20,118 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-04-24 17:56:20,135 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-04-24 17:56:20,159 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-04-24 17:56:20,751 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-04-24 17:56:20,774 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-04-24 17:56:20,799 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-04-24 17:56:20,827 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-04-24 17:56:20,855 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-04-24 17:56:20,878 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-04-24 17:56:20,899 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-04-24 17:56:20,924 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-04-24 17:56:20,951 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-04-24 17:56:20,973 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-04-24 17:56:21,197 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-04-24 17:56:21,215 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-04-24 17:56:21,235 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-04-24 17:56:21,256 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-04-24 17:56:21,276 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-04-24 17:56:21,296 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-04-24 17:56:21,315 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-04-24 17:56:21,336 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-04-24 17:56:21,355 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-04-24 17:56:21,377 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-04-24 17:56:21,611 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-04-24 17:56:21,631 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-04-24 17:56:21,652 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-04-24 17:56:21,673 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-04-24 17:56:21,689 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-04-24 17:56:21,714 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-04-24 17:56:21,735 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-04-24 17:56:21,756 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-04-24 17:56:21,775 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-04-24 17:56:21,798 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-04-24 17:56:22,021 [torchrl][INFO] Max num steps: 174, rb length 6500
# 2024-04-24 17:56:25,153 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-04-24 17:56:25,172 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-04-24 17:56:25,190 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-04-24 17:56:25,209 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-04-24 17:56:25,409 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-04-24 17:56:25,428 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-04-24 17:56:25,449 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-04-24 17:56:25,467 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-04-24 17:56:25,484 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-04-24 17:56:25,503 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-04-24 17:56:25,521 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-04-24 17:56:25,537 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-04-24 17:56:25,559 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-04-24 17:56:25,579 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-04-24 17:56:25,758 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-04-24 17:56:25,772 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-04-24 17:56:25,790 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-04-24 17:56:25,810 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-04-24 17:56:25,827 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-04-24 17:56:25,848 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-04-24 17:56:25,863 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-04-24 17:56:25,878 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-04-24 17:56:25,895 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-04-24 17:56:25,916 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-04-24 17:56:26,097 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-04-24 17:56:26,114 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-04-24 17:56:26,135 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-04-24 17:56:26,156 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-04-24 17:56:26,175 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-04-24 17:56:26,193 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-04-24 17:56:26,212 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-04-24 17:56:26,234 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-04-24 17:56:26,255 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-04-24 17:56:26,277 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-04-24 17:56:26,490 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-04-24 17:56:26,507 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-04-24 17:56:26,524 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-04-24 17:56:26,544 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-04-24 17:56:26,562 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-04-24 17:56:26,584 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-04-24 17:56:26,602 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-04-24 17:56:26,622 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-04-24 17:56:26,636 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-04-24 17:56:26,656 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-04-24 17:56:26,854 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-04-24 17:56:26,870 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-04-24 17:56:26,882 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-04-24 17:56:26,896 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-04-24 17:56:26,918 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-04-24 17:56:26,936 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-04-24 17:56:26,955 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-04-24 17:56:26,972 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-04-24 17:56:26,990 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-04-24 17:56:27,009 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-04-24 17:56:27,193 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-04-24 17:56:27,207 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-04-24 17:56:27,224 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-04-24 17:56:27,241 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-04-24 17:56:27,261 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-04-24 17:56:27,282 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-04-24 17:56:27,299 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-04-24 17:56:27,318 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-04-24 17:56:27,336 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-04-24 17:56:27,354 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-04-24 17:56:27,568 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-04-24 17:56:27,587 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-04-24 17:56:27,607 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-04-24 17:56:27,627 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-04-24 17:56:27,647 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-04-24 17:56:27,668 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-04-24 17:56:27,685 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-04-24 17:56:27,705 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-04-24 17:56:27,722 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-04-24 17:56:27,741 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-04-24 17:56:27,743 [torchrl][INFO] solved after 30000 steps, 1270 episodes and in 16.07404851913452s.

# %%
record_env.rollout(max_steps=1000, policy=policy)
video_recorder.dump()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 record_env.rollout(max_steps=1000, policy=policy)
#       2 video_recorder.dump()
#
# File D:\python39\lib\site-packages\torchrl\envs\common.py:2430, in EnvBase.rollout(self, max_steps, policy, callback, auto_reset, auto_cast_to_device, break_when_any_done, return_contiguous, tensordict, out)
#    2420 kwargs = {
#    2421     "tensordict": tensordict,
#    2422     "auto_cast_to_device": auto_cast_to_device,
#    (...)
#    2427     "callback": callback,
#    2428 }
#    2429 if break_when_any_done:
# -> 2430     tensordicts = self._rollout_stop_early(**kwargs)
#    2431 else:
#    2432     tensordicts = self._rollout_nonstop(**kwargs)
#
# File D:\python39\lib\site-packages\torchrl\envs\common.py:2467, in EnvBase._rollout_stop_early(self, tensordict, auto_cast_to_device, max_steps, policy, policy_device, env_device, callback)
#    2465     else:
#    2466         tensordict.clear_device_()
# -> 2467 tensordict = self.step(tensordict)
#    2468 tensordicts.append(tensordict.clone(False))
#    2470 if i == max_steps - 1:
#    2471     # we don't truncated as one could potentially continue the run
#
# File D:\python39\lib\site-packages\torchrl\envs\common.py:1409, in EnvBase.step(self, tensordict)
#    1406 self._assert_tensordict_shape(tensordict)
#    1407 next_preset = tensordict.get("next", None)
# -> 1409 next_tensordict = self._step(tensordict)
#    1410 next_tensordict = self._step_proc_data(next_tensordict)
#    1411 if next_preset is not None:
#    1412     # tensordict could already have a "next" key
#    1413     # this could be done more efficiently by not excluding but just passing
#    1414     # the necessary keys
#
# File D:\python39\lib\site-packages\torchrl\envs\transforms\transforms.py:748, in TransformedEnv._step(self, tensordict)
#     746 self.base_env._complete_done(self.base_env.full_done_spec, next_tensordict)
#     747 # we want the input entries to remain unchanged
# --> 748 next_tensordict = self.transform._step(tensordict, next_tensordict)
#     749 return next_tensordict
#
# File D:\python39\lib\site-packages\torchrl\envs\transforms\transforms.py:310, in Transform._step(self, tensordict, next_tensordict)
#     290 def _step(
#     291     self, tensordict: TensorDictBase, next_tensordict: TensorDictBase
#     292 ) -> TensorDictBase:
#     293     """The parent method of a transform during the ``env.step`` execution.
#     294
#     295     This method should be overwritten whenever the :meth:`~._step` needs to be
#    (...)
#     308     Returns: the data at t+1
#     309     """
# --> 310     next_tensordict = self._call(next_tensordict)
#     311     return next_tensordict
#
# File D:\python39\lib\site-packages\torchrl\envs\transforms\transforms.py:267, in Transform._call(self, tensordict)
#     265 value = tensordict.get(in_key, default=None)
#     266 if value is not None:
# --> 267     observation = self._apply_transform(value)
#     268     tensordict.set(
#     269         out_key,
#     270         observation,
#     271     )
#     272 elif not self.missing_tolerance:
#
# File D:\python39\lib\site-packages\torchrl\record\recorder.py:139, in VideoRecorder._apply_transform(self, observation)
#     136         from torchvision.utils import make_grid
#     138         observation_trsf = make_grid(observation_trsf)
# --> 139     self.obs.append(observation_trsf.to(torch.uint8))
#     140 return observation
#
# File D:\python39\lib\site-packages\torch\nn\modules\module.py:1688, in Module.__getattr__(self, name)
#    1686     if name in modules:
#    1687         return modules[name]
# -> 1688 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'VideoRecorder' object has no attribute 'obs'
